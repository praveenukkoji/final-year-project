# %% [markdown]
# # **Plant Disease Classification**
#
# ---
#
# ![alt text](https://cdn-images-1.medium.com/max/1200/1*FswlF4lZPQ4kT_gkybacZw.jpeg)
#
#
# # Introduction
#
# Getting affected by a disease is very common in plants due to various factors such as fertilizers, cultural practices followed, environmental conditions, etc. These diseases hurt agricultural yield and eventually the economy based on it.
#
# Any technique or method to overcome this problem and getting a warning before the plants are infected would aid farmers to efficiently cultivate crops or plants, both qualitatively and quantitatively. Thus, disease detection in plants plays a very important role in agriculture.

# %% [markdown]
# # Import Libraries

# %% [markdown]
# Importing necessary libraries and modules required to build the classification model.

# %%
import numpy as np
import pickle
import cv2
import os
import matplotlib.pyplot as plt
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential

#from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization

from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam

from keras.preprocessing import image

#from keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import img_to_array

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %% [markdown]
# Initializing a few parameters required for the image dataset preprocessing.

# %%
# Dimension of resized image
DEFAULT_IMAGE_SIZE = tuple((256, 256))

# Number of images used to train the model
N_IMAGES = 100

# Path to the dataset folder
root_dir = './PlantVillage'

train_dir = os.path.join(root_dir, 'train')
val_dir = os.path.join(root_dir, 'val')

# %% [markdown]
# We use the function `convert_image_to_array` to resize an image to the size `DEFAULT_IMAGE_SIZE` we defined above.

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None:
            image = cv2.resize(image, DEFAULT_IMAGE_SIZE)   
            return img_to_array(image)
        else:
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# Here, we load the training data images by traversing through all the folders and converting all the images and labels into separate lists respectively.
#
# *NOTE: We use a small portion of the entire dataset due to the computing limitations. Tweak `N_IMAGES` to include entire dataset.*

# %%
image_list, label_list = [], []

try:
    print("[INFO] Loading images ...")
    plant_disease_folder_list = listdir(train_dir)

    for plant_disease_folder in plant_disease_folder_list:
        print(f"[INFO] Processing {plant_disease_folder} ...")
        plant_disease_image_list = listdir(f"{train_dir}/{plant_disease_folder}/")

        for image in plant_disease_image_list[:N_IMAGES]:
            image_directory = f"{train_dir}/{plant_disease_folder}/{image}"
            if image_directory.endswith(".jpg")==True or image_directory.endswith(".JPG")==True:
                image_list.append(convert_image_to_array(image_directory))
                label_list.append(plant_disease_folder)

    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")

# Transform the loaded training image data into numpy array
np_image_list = np.array(image_list, dtype=np.float16) / 225.0
print()

# Check the number of images loaded for training
image_len = len(image_list)
print(f"Total number of images: {image_len}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Strawberry___healthy ...
# [INFO] Processing background ...
# [INFO] Processing Grape___Black_rot ...
# [INFO] Processing Potato___Early_blight ...
# [INFO] Processing Blueberry___healthy ...
# [INFO] Processing Corn_(maize)___healthy ...
# [INFO] Processing Tomato___Target_Spot ...
# [INFO] Processing Peach___healthy ...
# [INFO] Processing Potato___Late_blight ...
# [INFO] Processing Tomato___Late_blight ...
# [INFO] Processing Tomato___Tomato_mosaic_virus ...
# [INFO] Processing Pepper,_bell___healthy ...
# [INFO] Processing Orange___Haunglongbing_(Citrus_greening) ...
# [INFO] Processing Tomato___Leaf_Mold ...
# [INFO] Processing Grape___Leaf_blight_(Isariopsis_Leaf_Spot) ...
# [INFO] Processing Cherry_(including_sour)___Powdery_mildew ...
# [INFO] Processing Apple___Cedar_apple_rust ...
# [INFO] Processing Tomato___Bacterial_spot ...
# [INFO] Processing Grape___healthy ...
# [INFO] Processing Tomato___Early_blight ...
# [INFO] Processing Corn_(maize)___Common_rust_ ...
# [INFO] Processing Grape___Esca_(Black_Measles) ...
# [INFO] Processing Raspberry___healthy ...
# [INFO] Processing Tomato___healthy ...
# [INFO] Processing Cherry_(including_sour)___healthy ...
# [INFO] Processing Tomato___Tomato_Yellow_Leaf_Curl_Virus ...
# [INFO] Processing Apple___Apple_scab ...
# [INFO] Processing Corn_(maize)___Northern_Leaf_Blight ...
# [INFO] Processing Tomato___Spider_mites Two-spotted_spider_mite ...
# [INFO] Processing Peach___Bacterial_spot ...
# [INFO] Processing Pepper,_bell___Bacterial_spot ...
# [INFO] Processing Tomato___Septoria_leaf_spot ...
# [INFO] Processing Squash___Powdery_mildew ...
# [INFO] Processing Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ...
# [INFO] Processing Apple___Black_rot ...
# [INFO] Processing Apple___healthy ...
# [INFO] Processing Strawberry___Leaf_scorch ...
# [INFO] Processing Potato___healthy ...
# [INFO] Processing Soybean___healthy ...
# [INFO] Image loading completed
#
# Total number of images: 3900

# %% [markdown]
# Examine the labels/classes in the training dataset.

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)

pickle.dump(label_binarizer,open('plant_disease_label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

print("Total number of classes: ", n_classes)
# Out:
# Total number of classes:  39

# %% [markdown]
# # Augment and Split Dataset

# %% [markdown]
# Using `ImageDataGenerator` to augment data by performing various operations on the training images.

# %%
augment = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                             height_shift_range=0.1, shear_range=0.2, 
                             zoom_range=0.2, horizontal_flip=True, 
                             fill_mode="nearest")

# %% [markdown]
# Splitting the data into training and test sets for validation purpose.

# %%
print("[INFO] Splitting data to train and test...")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Splitting data to train and test...

# %% [markdown]
# # Build Model

# %% [markdown]
# Defining the hyperparameters of the plant disease classification model.

# %%
EPOCHS = 25
STEPS = 100
LR = 1e-3
BATCH_SIZE = 32
WIDTH = 256
HEIGHT = 256
DEPTH = 3

# %% [markdown]
# Creating a sequential model and adding Convolutional, Normalization, Pooling, Dropout and Activation layers at the appropriate positions.

# %%
model = Sequential()
inputShape = (HEIGHT, WIDTH, DEPTH)
chanDim = -1

if K.image_data_format() == "channels_first":
    inputShape = (DEPTH, HEIGHT, WIDTH)
    chanDim = 1

model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(n_classes))
model.add(Activation("softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 256, 256, 32)      896
#
#  activation_7 (Activation)   (None, 256, 256, 32)      0
#
#  batch_normalization_6 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 85, 85, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 85, 85, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 85, 85, 64)        18496
#
#  activation_8 (Activation)   (None, 85, 85, 64)        0
#
#  batch_normalization_7 (Batc  (None, 85, 85, 64)       256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 85, 85, 64)        36928
#
#  activation_9 (Activation)   (None, 85, 85, 64)        0
#
#  batch_normalization_8 (Batc  (None, 85, 85, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 42, 42, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 42, 42, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 42, 42, 128)       73856
#
#  activation_10 (Activation)  (None, 42, 42, 128)       0
#
#  batch_normalization_9 (Batc  (None, 42, 42, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 42, 42, 128)       147584
#
#  activation_11 (Activation)  (None, 42, 42, 128)       0
#
#  batch_normalization_10 (Bat  (None, 42, 42, 128)      512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 21, 21, 128)       0
#
#  flatten_1 (Flatten)         (None, 56448)             0
#
#  dense_2 (Dense)             (None, 1024)              57803776
#
#  activation_12 (Activation)  (None, 1024)              0
#
#  batch_normalization_11 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 39)                39975
#
#  activation_13 (Activation)  (None, 39)                0
#
# =================================================================
# Total params: 58,127,271
# Trainable params: 58,124,391
# Non-trainable params: 2,880
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %% [markdown]
# We initialize Adam optimizer with learning rate and decay parameters.
#
# Also, we choose the type of loss and metrics for the model and compile it for training.

# %%
# Initialize optimizer
opt = Adam(learning_rate=LR, decay=LR / EPOCHS)

# Compile model
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# Train model
print("[INFO] Training network...")
history = model.fit(augment.flow(x_train, y_train, batch_size=BATCH_SIZE),
                              validation_data=(x_test, y_test),
                              steps_per_epoch=len(x_train) // BATCH_SIZE,
                              epochs=EPOCHS, 
                              verbose=1)
# Out:
# [INFO] Training network...
# Epoch 1/25
# 97/97 [==============================] - 267s 3s/step - loss: 0.4432 - accuracy: 0.0570 - val_loss: 0.5099 - val_accuracy: 0.0154
# Epoch 2/25
# 97/97 [==============================] - 237s 2s/step - loss: 0.1592 - accuracy: 0.1312 - val_loss: 0.1427 - val_accuracy: 0.0603
# Epoch 3/25
# 97/97 [==============================] - 233s 2s/step - loss: 0.1233 - accuracy: 0.2095 - val_loss: 0.2853 - val_accuracy: 0.0218
# Epoch 4/25
# 97/97 [==============================] - 282s 3s/step - loss: 0.1150 - accuracy: 0.2481 - val_loss: 0.1915 - val_accuracy: 0.1410
# Epoch 5/25
# 97/97 [==============================] - 243s 2s/step - loss: 0.1036 - accuracy: 0.3255 - val_loss: 0.1521 - val_accuracy: 0.0962
# Epoch 6/25
# 97/97 [==============================] - 260s 3s/step - loss: 0.0921 - accuracy: 0.3779 - val_loss: 0.1020 - val_accuracy: 0.3987
# Epoch 7/25
# 97/97 [==============================] - 266s 3s/step - loss: 0.0827 - accuracy: 0.4618 - val_loss: 0.1660 - val_accuracy: 0.1321
# Epoch 8/25
# 97/97 [==============================] - 252s 3s/step - loss: 0.0787 - accuracy: 0.4984 - val_loss: 0.1005 - val_accuracy: 0.3346
# Epoch 9/25
# 97/97 [==============================] - 252s 3s/step - loss: 0.0759 - accuracy: 0.4835 - val_loss: 0.1755 - val_accuracy: 0.1769
# Epoch 10/25
# 97/97 [==============================] - 247s 3s/step - loss: 0.0715 - accuracy: 0.5282 - val_loss: 0.1368 - val_accuracy: 0.2372
# Epoch 11/25
# 97/97 [==============================] - 268s 3s/step - loss: 0.0735 - accuracy: 0.5003 - val_loss: 0.2306 - val_accuracy: 0.1615
# Epoch 12/25
# 97/97 [==============================] - 276s 3s/step - loss: 0.0646 - accuracy: 0.5693 - val_loss: 0.0961 - val_accuracy: 0.3962
# Epoch 13/25
# 97/97 [==============================] - 266s 3s/step - loss: 0.0603 - accuracy: 0.6004 - val_loss: 0.2161 - val_accuracy: 0.2487
# Epoch 14/25
# 97/97 [==============================] - 252s 3s/step - loss: 0.0578 - accuracy: 0.6292 - val_loss: 0.0683 - val_accuracy: 0.5385
# Epoch 15/25
# 97/97 [==============================] - 246s 3s/step - loss: 0.0592 - accuracy: 0.6227 - val_loss: 0.0668 - val_accuracy: 0.5423
# Epoch 16/25
# 97/97 [==============================] - 261s 3s/step - loss: 0.0580 - accuracy: 0.6231 - val_loss: 0.0862 - val_accuracy: 0.4603
# Epoch 17/25
# 97/97 [==============================] - 267s 3s/step - loss: 0.0515 - accuracy: 0.6687 - val_loss: 0.0548 - val_accuracy: 0.6385
# Epoch 18/25
# 97/97 [==============================] - 285s 3s/step - loss: 0.0479 - accuracy: 0.6959 - val_loss: 0.0700 - val_accuracy: 0.5910
# Epoch 19/25
# 97/97 [==============================] - 281s 3s/step - loss: 0.0489 - accuracy: 0.6914 - val_loss: 0.1584 - val_accuracy: 0.3064
# Epoch 20/25
# 97/97 [==============================] - 291s 3s/step - loss: 0.0440 - accuracy: 0.7257 - val_loss: 0.1062 - val_accuracy: 0.4128
# Epoch 21/25
# 97/97 [==============================] - 280s 3s/step - loss: 0.0409 - accuracy: 0.7506 - val_loss: 0.0651 - val_accuracy: 0.5795
# Epoch 22/25
# 97/97 [==============================] - 261s 3s/step - loss: 0.0420 - accuracy: 0.7445 - val_loss: 0.1509 - val_accuracy: 0.3436
# Epoch 23/25
# 97/97 [==============================] - 248s 3s/step - loss: 0.0394 - accuracy: 0.7468 - val_loss: 0.0491 - val_accuracy: 0.6667
# Epoch 24/25
# 97/97 [==============================] - 232s 2s/step - loss: 0.0385 - accuracy: 0.7730 - val_loss: 0.0515 - val_accuracy: 0.6590
# Epoch 25/25
# 97/97 [==============================] - 231s 2s/step - loss: 0.0385 - accuracy: 0.7503 - val_loss: 0.0662 - val_accuracy: 0.5885

# %% [markdown]
# # Evaluate Model

# %% [markdown]
# Comparing the accuracy and loss by plotting the graph for training and validation.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()

# Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# Evaluating model accuracy by using the `evaluate` method

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 25/25 [==============================] - 17s 663ms/step - loss: 0.0662 - accuracy: 0.5885
# Test Accuracy: 58.84615182876587

# %% [markdown]
# # Save Model

# %%
# Dump pickle file of the model
print("[INFO] Saving model...")
pickle.dump(model,open('plant_disease_classification_model.pkl', 'wb'))
# Out:
# [INFO] Saving model...
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://b208d912-1b15-4627-b2fd-ec5053fa5eaa/assets
# INFO:tensorflow:Assets written to: ram://b208d912-1b15-4627-b2fd-ec5053fa5eaa/assets

# %%
# Dump pickle file of the labels
print("[INFO] Saving label transform...")
filename = 'plant_disease_label_transform.pkl'
image_labels = pickle.load(open(filename, 'rb'))
# Out:
# [INFO] Saving label transform...

# %% [markdown]
# # Test Model

# %% [markdown]
# We write the following `predict_disease` function to predict the class or disease of a plant image.
#
# We just need to provide the complete path to the image and it displays the image along with its prediction class or plant disease.

# %%
def predict_disease(image_path):
    image_array = convert_image_to_array(image_path)
    np_image = np.array(image_array, dtype=np.float16) / 225.0
    np_image = np.expand_dims(np_image,0)
    plt.imshow(plt.imread(image_path))
    
    #result = model.predict_classes(np_image)
    
    predict_x=model.predict(np_image) 
    classes_x=np.argmax(predict_x,axis=1)

    print((image_labels.classes_[classes_x][0]))

# %% [markdown]
# For testing purposes, we randomly choose images from the dataset and try predicting class or disease of the plant image.

# %%
predict_disease('PlantVillage/val/Blueberry___healthy/008c85d0-a954-4127-bd26-861dc8a1e6ff___RS_HL 2431.JPG')
# Out:
# 1/1 [==============================] - 1s 756ms/step
# Blueberry___healthy

# %%
predict_disease('PlantVillage/val/Potato___Early_blight/03b0d3c1-b5b0-48f4-98aa-f8904670290f___RS_Early.B 7051.JPG')
# Out:
# 1/1 [==============================] - 0s 56ms/step
# Potato___Early_blight

# %%
predict_disease('PlantVillage/val/Tomato___Target_Spot/1006b3dd-22d8-41b8-b83d-08bf189fcdaa___Com.G_TgS_FL 8118.JPG')
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Tomato___Tomato_mosaic_virus

# %%
predict_disease('PlantVillage/val/Orange___Haunglongbing_(Citrus_greening)/02459e0c-a189-4dc9-a0dc-0548e36d0efb___CREC_HLB 5714.JPG')
# Out:
# 1/1 [==============================] - 0s 52ms/step
# Orange___Haunglongbing_(Citrus_greening)

# %% [markdown]
# # Reuse Model

# %% [markdown]
# We download the trained model and label transform saved in the Google Drive.

# %%
# Download the trained model file based on its file ID.
file_id = '1E5jNzpM__7z67GRl1cbhHK71yKcPa8wl'
# !gdown https://drive.google.com/uc?id={file_id}

# Download the labels file based on its file ID.
file_id = '1WsgEd3TG33Vj_9AAAT_WfJe_AqsuC9uu'
# !gdown https://drive.google.com/uc?id={file_id}
# Out:
# zsh:1: no matches found: https://drive.google.com/uc?id=1E5jNzpM__7z67GRl1cbhHK71yKcPa8wl
# zsh:1: no matches found: https://drive.google.com/uc?id=1WsgEd3TG33Vj_9AAAT_WfJe_AqsuC9uu

# %% [markdown]
# Importing necessary libraries and modules required to build the classification model.

# %%
import numpy as np
import pickle
import cv2
import os
import matplotlib.pyplot as plt
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential

#from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization

from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam

from keras.preprocessing import image

#from keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import img_to_array

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load the trained model and its labels for prediction.

# %%
# Load model
filename = 'plant_disease_classification_model.pkl'
model = pickle.load(open(filename, 'rb'))

# Load labels
filename = 'plant_disease_label_transform.pkl'
image_labels = pickle.load(open(filename, 'rb'))

# %% [markdown]
# We use the `convert_image_to_array` function to resize an image and `predict_disease` function to predict the class or disease of a plant image.
#
# We just need to provide the complete path to the image and it displays the image along with its prediction class or plant disease.

# %%
# Dimension of resized image
DEFAULT_IMAGE_SIZE = tuple((256, 256))

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None:
            image = cv2.resize(image, DEFAULT_IMAGE_SIZE)   
            return img_to_array(image)
        else:
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

def predict_disease(image_path):
    image_array = convert_image_to_array(image_path)
    np_image = np.array(image_array, dtype=np.float16) / 225.0
    np_image = np.expand_dims(np_image,0)
    plt.imshow(plt.imread(image_path))
    
    #result = model.predict_classes(np_image)
    
    predict_x=model.predict(np_image) 
    classes_x=np.argmax(predict_x,axis=1)

    print((image_labels.classes_[classes_x][0]))

# %% [markdown]
# Predict disease of any plant image.

# %%
predict_disease('PlantVillage/val/Corn_(maize)___Northern_Leaf_Blight/028159fc-995e-455a-8d60-6d377580a898___RS_NLB 4023.JPG')
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Corn_(maize)___Northern_Leaf_Blight
